# %%
import h5py
# Out:
# C:\Users\Sanjal\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import pandas as pd

# %%
import numpy as np

# %%
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Dense, Activation, Flatten
from keras.layers import merge, Input
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
from scipy.io import loadmat
from datetime import datetime
import os

# %%
from keras.models import load_model, Model

# %%
from keras.utils import np_utils

# %%
model = load_model("weights.29-3.76_utk.hdf5")

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  18432       activation_1[0][0]
# ...

# %%
last_layer = model.get_layer('average_pooling2d_1').output

# %%
model.input
# Out:
# <tf.Tensor 'input_1:0' shape=(?, 64, 64, 3) dtype=float32>

# %%
def load_data(path):
    d = loadmat(path)
    return d["image"], d["gender"][0], d["age"][0], d["db"][0], d["img_size"][0, 0], d["min_score"][0, 0]

# %%
print("Loading data...")
image, gender, age, _, image_size, _ = load_data("age-gender-estimation-master\data\imdb_db")
# Out:
# Loading data...

# %%
image_size
# Out:
# 64

# %%
image.shape
# Out:
# (171852, 64, 64, 3)

# %%
gender.shape
# Out:
# (171852,)

# %%
age.shape
# Out:
# (171852,)

# %%
X_data = image
y_data_g = np_utils.to_categorical(gender, 2)
y_data_a = np_utils.to_categorical(age, 101)

# %%
X_data.shape
# Out:
# (171852, 64, 64, 3)

# %%
image_input = Input(shape=(64, 64, 3))

# %%
x= Flatten(name='flatten')(last_layer)

# %%
x = Dense(128, activation='relu', name='fc1')(x)

# %%
predictions_g = Dense(2, activation='softmax', name='gender')(x)

# %%
predictions_a = Dense(101, activation='softmax', name='age')(x)

# %%
model_custom = Model(model.get_layer('input_1').output, [predictions_g, predictions_a])

# %%
model_custom.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  18432       activation_1[0][0]
# ...

# %%
for layer in model_custom.layers[:-3]:
    layer.trainable = False

# %%
model_custom.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  18432       activation_1[0][0]
# ...

# %%
model_custom.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
type(age)
# Out:
# numpy.ndarray

# %%
X_data1=X_data[0:20000]
X_data2=X_data[20000:40000]
X_data3=X_data[40000:60000]
X_data4=X_data[60000:80000]
X_data5=X_data[80000:100000]
X_data6=X_data[100000:120000]
X_data7=X_data[120000:140000]
X_data8=X_data[140000:171852]
y_data_g1=y_data_g[0:20000]
y_data_g2=y_data_g[20000:40000]
y_data_g3=y_data_g[40000:60000]
y_data_g4=y_data_g[60000:80000]
y_data_g5=y_data_g[80000:100000]
y_data_g6=y_data_g[100000:120000]
y_data_g7=y_data_g[120000:140000]
y_data_g8=y_data_g[140000:171852]
y_data_a1=y_data_a[0:20000]
y_data_a2=y_data_a[20000:40000]
y_data_a3=y_data_a[40000:60000]
y_data_a4=y_data_a[60000:80000]
y_data_a5=y_data_a[80000:100000]
y_data_a6=y_data_a[100000:120000]
y_data_a7=y_data_a[120000:140000]
y_data_a8=y_data_a[140000:171852]

# %%
x_train1,y_train_g1,y_train_a1=shuffle(X_data1, y_data_g1,y_data_a1, random_state=2)

# %%
x_train2,y_train_g2,y_train_a2=shuffle(X_data2, y_data_g2,y_data_a2, random_state=2)

# %%
x_train3,y_train_g3,y_train_a3=shuffle(X_data3, y_data_g3,y_data_a3, random_state=2)

# %%
x_train4,y_train_g4,y_train_a4=shuffle(X_data4, y_data_g4,y_data_a4, random_state=2)

# %%
x_train5,y_train_g5,y_train_a5=shuffle(X_data5, y_data_g5,y_data_a5, random_state=2)

# %%
x_train6,y_train_g6,y_train_a6=shuffle(X_data6, y_data_g6,y_data_a6, random_state=2)

# %%
x_train7,y_train_g7,y_train_a7=shuffle(X_data7, y_data_g7,y_data_a7, random_state=2)

# %%
x_train8,y_train_g8,y_train_a8=shuffle(X_data8, y_data_g8,y_data_a8, random_state=2)

# %%
x_train=[]
x_train=list(x_train1[0:10000])+list(x_train2[0:10000])

# %%
len(x_train)
# Out:
# 20000

# %%
x_train=[]
y_train_g=list(y_train_g1[0:10000])+list(y_train_g2[0:10000])

# %%
len(y_train_g)
# Out:
# 20000

# %%
y_train_a=[]
y_train_a=list(y_train_a1[0:10000])+list(y_train_a2[0:10000])

# %%
len(y_train_a)
# Out:
# 20000

# %%
x_train1=np.array(x_train[0:1000])
y_train_g1=np.array(y_train_g[0:1000])
y_train_a1=np.array(y_train_a[0:1000])

# %%
model_custom.fit(x_train1, [y_train_g1, y_data_a1], batch_size=32, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-e91f37c0b802> in <module>()
# ----> 1 model_custom.fit(x_train1, [y_train_g1, y_data_a1], batch_size=32, epochs=10)
#
# D:\work\envs\tensorflow\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     948             sample_weight=sample_weight,
#     949             class_weight=class_weight,
# --> 950             batch_size=batch_size)
#     951         # Prepare validation data.
#     952         do_validation = False
#
# D:\work\envs\tensorflow\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     747             feed_input_shapes,
# ...

# %%
model_custom.fit(X_data[0:1000], [y_data_g[0:1000], y_data_a[0:1000]], batch_size=64, epochs=8)
# Out:
# Epoch 1/8
# 1000/1000 [==============================] - 749s 749ms/step - loss: 4.7737 - gender_loss: 0.3839 - age_loss: 4.2992 - gender_acc: 0.8440 - age_acc: 0.0390
# Epoch 2/8
# 1000/1000 [==============================] - 685s 685ms/step - loss: 3.7900 - gender_loss: 0.1806 - age_loss: 3.5188 - gender_acc: 0.9360 - age_acc: 0.1860
# Epoch 3/8
# 1000/1000 [==============================] - 687s 687ms/step - loss: 3.2520 - gender_loss: 0.1600 - age_loss: 3.0014 - gender_acc: 0.9430 - age_acc: 0.3050
# Epoch 4/8
# 1000/1000 [==============================] - 687s 687ms/step - loss: 2.8414 - gender_loss: 0.1288 - age_loss: 2.6221 - gender_acc: 0.9540 - age_acc: 0.3820
# Epoch 5/8
# 1000/1000 [==============================] - 689s 689ms/step - loss: 2.5031 - gender_loss: 0.1110 - age_loss: 2.3016 - gender_acc: 0.9600 - age_acc: 0.4750
# Epoch 6/8
# ...

# %%
(loss2)=model_custom.evaluate(X_data[20000:21000], [y_data_g[20000:21000], y_data_a[20000:21000]],batch_size=100)

# %%
loss1=model_custom.evaluate(X_data[20000:20010], [y_data_g[20000:20010], y_data_a[20000:20010]],batch_size=1,verbose=1)
# Out:
# 10/10 [==============================] - 9s 916ms/step

# %%
print(loss1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-169a0cfce501> in <module>()
# ----> 1 print(loss1)
#
# NameError: name 'loss1' is not defined

# %%
print (preds)
# Out:
# [array([[0.9767527 , 0.02324734],
#        [0.995691  , 0.00430896],
#        [0.9978942 , 0.00210581],
#        [0.39328685, 0.6067131 ],
#        [0.95892304, 0.0410769 ],
#        [0.99752635, 0.00247365],
#        [0.99539584, 0.0046042 ],
#        [0.9964407 , 0.00355926],
#        [0.68231493, 0.317685  ],
#        [0.96987176, 0.03012826]], dtype=float32), array([[1.77707591e-07, 2.43548802e-05, 3.84412914e-07, ...,
#         2.56535459e-05, 1.60208183e-05, 1.14666626e-07],
#        [5.01210479e-07, 2.75148486e-05, 1.17338311e-06, ...,
#         5.83433903e-05, 1.21942168e-04, 2.21764182e-07],
#        [1.00566331e-06, 7.62595300e-05, 8.36969321e-06, ...,
#         3.07413400e-04, 3.18364218e-05, 9.78684625e-07],
#        ...,
#        [2.04509615e-06, 1.96130481e-04, 1.05199058e-06, ...,
#         1.17415468e-04, 9.04070021e-06, 6.53558459e-07],
#        [1.73557805e-06, 4.20207070e-05, 5.76517959e-06, ...,
#         2.53715465e-04, 2.86748509e-05, 8.38901826e-07],
# ...

# %%
from keras.models import model_from_json

# %%
model_json = model_custom.to_json()
with open("model_json", "w") as json_file:
    json_file.write(model_json)
model_custom.save_weights("model_custom_weights1.h5")
print("saved model to hard disk")
# Out:
# saved model to hard dick

# %%
# load json and create model
json_file = open('model_json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model_custom_weights1.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
loaded_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   432         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  18432       activation_1[0][0]
# ...

# %%
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
score = loaded_model.evaluate(X_data[20000:20010], [y_data_g[20000:20010], y_data_a[20000:20010]], verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# gender_loss: 14.29%

# %%
loaded_model.metrics_names[0]
# Out:
# 'loss'

# %%
print(score[0]*100)
# Out:
# 29.394957423210144

# %%
loaded_model.metrics_names[1]
# Out:
# 'gender_loss'

# %%
print(score[1]*100)
# Out:
# 14.286211133003235

# %%
loaded_model.metrics_names[2]
# Out:
# 'age_loss'

# %%
print(score[2]*100)
# Out:
# 6.050504371523857

# %%
loaded_model.metrics_names[3]
# Out:
# 'gender_acc'

# %%
print(score[3]*100)
# Out:
# 89.99999761581421

# %%
loaded_model.metrics_names[4]
# Out:
# 'age_acc'

# %%
print(score[4]*100)
# Out:
# 99.00990724563599

# %%
score
# Out:
# [0.29394957423210144,
#  0.14286211133003235,
#  0.06050504371523857,
#  0.8999999761581421,
#  0.9900990724563599]

# %%
score = loaded_model.evaluate(X_data[20000:21000], [y_data_g[20000:21000], y_data_a[20000:21000]], verbose=0)

# %%
score
# Out:
# [0.49972639203071595,
#  0.346576384305954,
#  0.0625676281452179,
#  0.903,
#  0.9896732754707337]
